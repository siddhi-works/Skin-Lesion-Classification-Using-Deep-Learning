# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhi-works/Skin-Lesion-Classification-Using-Deep-Learning/blob/main/skin_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kagglehub
path = kagglehub.dataset_download("bhaveshmittal/melanoma-cancer-dataset")
# Out:
# Using Colab cache for faster access to the 'melanoma-cancer-dataset' dataset.

# %%
import os
os.listdir(path)
# Out:
# ['test', 'train']

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Dataset path
BASE_DIR = path

TRAIN_DIR = os.path.join(BASE_DIR, "train")
TEST_DIR = os.path.join(BASE_DIR, "test")

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Train data
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary"
)

# Test data
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary"
)

print("Class Mapping:", train_generator.class_indices)
# Out:
# Found 11879 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Class Mapping: {'Benign': 0, 'Malignant': 1}

# %% [markdown]
# # **2. EXPLOTARY DATA ANALYSIS**

# %%
# Display some sample images from dataset
def plot_images(generator):
    images, labels = next(generator)  # Get a batch
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(images[i])
        plt.title("Cancer" if labels[i] == 1 else "Non-Cancer")
        plt.axis("off")
    plt.show()

# Plot Training Images
plot_images(train_generator)

# %% [markdown]
# # **3. CNN MODEL**

# %%
from tensorflow.keras import layers, models

# Build the CNN model
model = models.Sequential([
    # 1st Convolution Block
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    layers.MaxPooling2D((2, 2)),

    # 2nd Convolution Block
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # 3rd Convolution Block
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Flattening Layer
    layers.Flatten(),

    # Fully Connected Layers
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),  # Dropout to reduce overfitting
    layers.Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam',  # Optimizer for faster convergence
              loss='binary_crossentropy',  # Binary classification loss
              metrics=['accuracy'])  # Accuracy metric

# Model Summary
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,609 (169.36 MB)
#  Trainable params: 44,396,609 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **3. TRAIN AND EVALUATE MODEL**

# %%
# EarlyStopping to stop training when the model stops improving
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=5,  # Stop training after 5 epochs with no improvement
    restore_best_weights=True,
    verbose=1
)

# ReduceLROnPlateau to reduce the learning rate if the model stops improving
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=3,  # Reduce LR if no improvement after 3 epochs
    min_lr=1e-7,
    verbose=1
)


history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=30,  # Set number of epochs to train the model
    validation_data=test_generator,
    validation_steps=test_generator.samples // BATCH_SIZE,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 203s 535ms/step - accuracy: 0.7661 - loss: 0.4948 - val_accuracy: 0.7188 - val_loss: 0.5259 - learning_rate: 0.0010
# Epoch 2/30
#   1/371 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.8125 - loss: 0.4440
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8125 - loss: 0.4440 - val_accuracy: 0.6633 - val_loss: 0.5719 - learning_rate: 0.0010
# Epoch 3/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 169s 456ms/step - accuracy: 0.8081 - loss: 0.4258 - val_accuracy: 0.7923 - val_loss: 0.4334 - learning_rate: 0.0010
# Epoch 4/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9375 - loss: 0.2017 - val_accuracy: 0.7898 - val_loss: 0.4351 - learning_rate: 0.0010
# Epoch 5/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 168s 453ms/step - accuracy: 0.8248 - loss: 0.3909 - val_accuracy: 0.7344 - val_loss: 0.5554 - learning_rate: 0.0010
# Epoch 6/30
#   1/371 ━━━━━━━━━━━━━━━━━━━━ 28s 78ms/step - accuracy: 0.7812 - loss: 0.4665
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7812 - loss: 0.4665 - val_accuracy: 0.7359 - val_loss: 0.5667 - learning_rate: 0.0010
# Epoch 7/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 168s 452ms/step - accuracy: 0.8442 - loss: 0.3535 - val_accuracy: 0.8624 - val_loss: 0.3284 - learning_rate: 3.0000e-04
# Epoch 8/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8438 - loss: 0.3594 - val_accuracy: 0.8674 - val_loss: 0.3252 - learning_rate: 3.0000e-04
# Epoch 9/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 167s 448ms/step - accuracy: 0.8482 - loss: 0.3447 - val_accuracy: 0.8629 - val_loss: 0.3241 - learning_rate: 3.0000e-04
# Epoch 10/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8125 - loss: 0.3995 - val_accuracy: 0.8674 - val_loss: 0.3199 - learning_rate: 3.0000e-04
# Epoch 11/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 168s 454ms/step - accuracy: 0.8498 - loss: 0.3404 - val_accuracy: 0.8705 - val_loss: 0.3199 - learning_rate: 3.0000e-04
# Epoch 12/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8125 - loss: 0.3719 - val_accuracy: 0.8664 - val_loss: 0.3253 - learning_rate: 3.0000e-04
# Epoch 13/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.8511 - loss: 0.3390
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 169s 455ms/step - accuracy: 0.8562 - loss: 0.3335 - val_accuracy: 0.8589 - val_loss: 0.3229 - learning_rate: 3.0000e-04
# Epoch 14/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7812 - loss: 0.5819 - val_accuracy: 0.8579 - val_loss: 0.3273 - learning_rate: 9.0000e-05
# Epoch 15/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 202s 544ms/step - accuracy: 0.8607 - loss: 0.3220 - val_accuracy: 0.8805 - val_loss: 0.3013 - learning_rate: 9.0000e-05
# Epoch 16/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.3631 - val_accuracy: 0.8810 - val_loss: 0.2996 - learning_rate: 9.0000e-05
# Epoch 17/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 165s 446ms/step - accuracy: 0.8623 - loss: 0.3180 - val_accuracy: 0.8816 - val_loss: 0.3061 - learning_rate: 9.0000e-05
# Epoch 18/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8438 - loss: 0.2832 - val_accuracy: 0.8836 - val_loss: 0.3023 - learning_rate: 9.0000e-05
# Epoch 19/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 164s 443ms/step - accuracy: 0.8631 - loss: 0.3101 - val_accuracy: 0.8936 - val_loss: 0.2897 - learning_rate: 9.0000e-05
# Epoch 20/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9375 - loss: 0.1506 - val_accuracy: 0.8911 - val_loss: 0.2914 - learning_rate: 9.0000e-05
# Epoch 21/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 166s 446ms/step - accuracy: 0.8692 - loss: 0.3092 - val_accuracy: 0.8790 - val_loss: 0.3094 - learning_rate: 9.0000e-05
# Epoch 22/30
#   1/371 ━━━━━━━━━━━━━━━━━━━━ 30s 82ms/step - accuracy: 0.8438 - loss: 0.4395
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.4395 - val_accuracy: 0.8760 - val_loss: 0.3124 - learning_rate: 9.0000e-05
# Epoch 23/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 199s 449ms/step - accuracy: 0.8740 - loss: 0.3000 - val_accuracy: 0.8901 - val_loss: 0.2948 - learning_rate: 2.7000e-05
# Epoch 24/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9062 - loss: 0.2775 - val_accuracy: 0.8881 - val_loss: 0.2959 - learning_rate: 2.7000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %%
# Save Model
model.save("skin_cancer_cnn.h5")

# Plot Training History
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # **5. Evaluate Model Performance**

# %%
# Predict on the test set
test_pred = model.predict(test_generator, steps=test_generator.samples // BATCH_SIZE, verbose=1)

# Convert predictions to binary labels (0 or 1)
test_pred_labels = (test_pred > 0.5).astype("int32")

# Get the true labels
test_true_labels = test_generator.classes[:len(test_pred_labels)]  # Match length to predictions

# Classification report
print("Classification Report:")
print(classification_report(test_true_labels, test_pred_labels))

# Confusion Matrix
cm = confusion_matrix(test_true_labels, test_pred_labels)

# Plot Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      0.53      0.52      1000
#            1       0.50      0.48      0.49       984
#
#     accuracy                           0.51      1984
#    macro avg       0.50      0.50      0.50      1984
# weighted avg       0.50      0.51      0.50      1984

# %% [markdown]
# # **6. Prediction System**

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load the entire model
model = load_model('skin_cancer_cnn.h5')


def predict_skin_cancer(image_path, model):
    img = image.load_img(image_path, target_size=(224, 224))  # Load Image
    img_array = image.img_to_array(img) / 255.0  # Normalize
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Make Prediction
    prediction = model.predict(img_array)
    class_label = "Malignant" if prediction > 0.5 else "Benign"

    # Show Image with Prediction
    plt.imshow(img)
    plt.title(f"Predicted: {class_label}")
    plt.axis("off")
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Test on new image
predict_skin_cancer("/kaggle/input/melanoma-cancer-dataset/test/Malignant/5616.jpg", model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save("/content/drive/MyDrive/skin_cancer_cnn.keras")

# %%
model.save("/content/drive/MyDrive/skin_cancer_cnn.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1596/2453581189.py in <cell line: 0>()
# ----> 1 model.save("/content/drive/MyDrive/skin_cancer_cnn.h5")
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import load_model

model = load_model("My Drive/skin_cancer_cnn.keras")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8024/302970605.py in <cell line: 0>()
#       1 from tensorflow.keras.models import load_model
#       2
# ----> 3 model = load_model("My Drive/skin_cancer_cnn.keras")
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     201         )
#     202     elif str(filepath).endswith(".keras"):
# --> 203         raise ValueError(
#     204             f"File not found: filepath={filepath}. "
#     205             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=My Drive/skin_cancer_cnn.keras. Please ensure the file is an accessible `.keras` zip file.
